# %% [markdown]
# ---
# Известно, что генеральная совокупность распределена нормально
# со средним квадратическим отклонением, равным 16.
# Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95,
# если выборочная средняя M = 80, а объем выборки n = 256.

# %%
import numpy as np

# %%
n = 256
std_x = 16
M = 80
samples = np.random.normal(M, std_x, size = n)
samples
# Out:
# array([ 90.42746128,  55.69586915,  85.83873983, 106.52647036,
#         75.56054967,  55.10418221, 103.08436299,  82.60778044,
#         55.02367866,  63.80165457,  67.26272895,  63.08671494,
#         88.24820529,  76.66090344,  79.65073603,  69.69865432,
#        103.56469198,  50.57167327,  83.80395471,  67.05819739,
#         92.57522964,  74.17227109,  88.85755712, 109.15412877,
#         62.75014745,  77.18084074,  27.73092353,  50.60883261,
#         79.53214742,  75.60453671,  27.22815714,  80.18736583,
#         53.95799361,  68.31837722, 101.59060424, 102.84632353,
#         75.35989826,  67.04586824,  75.37999457,  82.38318789,
#         72.18501535,  81.96038725,  97.81012266,  89.48097133,
#         86.49154484,  96.009081  ,  57.89600732,  89.23109446,
#         74.30733098, 112.85218667,  70.06445197,  75.28255943,
#         41.5917308 ,  77.12566866,  74.02012507,  98.19904556,
#         80.13548117,  86.62018357,  94.34092009,  80.37562017,
# ...

# %%
(M - 2 * np.sqrt(M / n), M + 2 * np.sqrt(M / n))
# Out:
# (78.8819660112501, 81.1180339887499)

# %% [markdown]
# ---
# В результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью,
# получены опытные данные:
#
# 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1
#
# Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей,
# оценить истинное значение величины X при помощи доверительного интервала, покрывающего это
# значение с доверительной вероятностью 0,95.

# %%
samples = np.array([6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1])

# %%
std_s = samples.std(ddof=1)
mean_s = samples.mean()
print(std_s, mean_s)
# Out:
# 0.4508017549014448 6.590000000000001

# %% [markdown]
# Из таблицы квантили получаем, что:

# %%
t = 2.2622
t
# Out:
# 2.2622

# %%
n = 10
n
# Out:
# 10

# %%
mean_s
# Out:
# 6.590000000000001

# %%
(mean_s - t * std_s / np.sqrt(n), mean_s + t * std_s / np.sqrt(n))
# Out:
# (6.267509744706053, 6.912490255293949)

# %% [markdown]
# ---
# Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм.
#
# Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр
#
# оказался равным 17.5 мм, а дисперсия известна и равна 4 мм.

# %%
disp = 4
n = 100
a = 0.05
m = 17.5
std_s = np.sqrt(disp)
std_s
# Out:
# 2.0

# %%
samples = np.random.normal(m, std_s, size=n)
samples
# Out:
# array([15.15794254, 16.78184844, 13.6266733 , 21.56130036, 20.65080489,
#        14.03240731, 16.38603561, 19.35680614, 16.60481858, 18.15149886,
#        16.77874638, 15.71711607, 15.79573105, 15.85985026, 17.67767075,
#        17.62328414, 14.57200665, 19.71650335, 20.21454036, 18.14887965,
#        15.00033635, 17.71967437, 18.94857351, 16.35132603, 16.2708598 ,
#        17.8101915 , 20.9638308 , 15.8258944 , 19.81601297, 15.74649148,
#        18.73562961, 18.92317052, 19.36062808, 18.75503519, 15.1855136 ,
#        17.27220165, 20.42030923, 17.70229181, 16.42732896, 18.11305436,
#        18.27508111, 15.65180169, 16.89281653, 16.19168913, 17.50840361,
#        15.12986947, 21.19715969, 22.3620184 , 16.22184346, 21.57405402,
#        15.39326415, 20.04674275, 16.62085993, 17.54447765, 16.51892271,
#        15.15348711, 18.38713431, 18.42017244, 19.02661386, 15.58433068,
#        17.38314964, 16.55011933, 19.47342369, 15.6419854 , 15.5019954 ,
# ...

# %% [markdown]
# 1. Нулевая гипотеза изготовленные автоматическим станком, имеют средний диаметр 17 мм, ненулевая соотвественно не имеют такого диаметра
# 2. Двустороння функция

# %% [markdown]
# *** Что-то совсем запутался в дисперсиях, ско и сигмах, что есть что в конспектах, если правильно понял, то следующее действие такое:

# %%
m_gip = 17
(m_gip - ((std_s * 2) / np.sqrt(n)), m_gip + ((std_s * 2) / np.sqrt(n)))
# Out:
# (16.6, 17.4)

# %% [markdown]
# Это мы нашли доверительный интервал, получается, что гипотеза верна

# %% [markdown]
# ---
# Продавец утверждает, что средний вес пачки печенья составляет 200 г.
# Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет:
#
# 202, 203, 199, 197, 195, 201, 200, 204, 194, 190.
#
# Известно, что их веса распределены нормально.
#
# Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?

# %%
samples = np.array([202, 203, 199, 197, 195, 201, 200, 204, 194, 190])
m = 200
a = 0,99

# %%
std_s = samples.std()
mean_s = samples.mean()
std_s, mean_s
# Out:
# (4.224926034855522, 198.5)

# %% [markdown]
# В этом случае необходимо решать через критерий t

# %%
t = 2.8214
n = 10

# %%
(mean_s - t * std_s / np.sqrt(n), mean_s + t * std_s / np.sqrt(n))
# Out:
# (194.73049978662954, 202.26950021337046)

# %% [markdown]
# Итак получается, что наша гипотеза подтвердилась, так как 200 гр входит в доверительных интервал
